# %% [markdown]
# ### <center> Algorithm Steps </center>
#
# - **Loaded the data**: Started by loading the student data from a CSV file into a Pandas DataFrame.
# - **Displayed the original records**: Printed out the original student records to ensure the data was loaded correctly.
# - **Sorted the data**: Sorted the DataFrame by profession in ascending order and by score in descending order.
# - **Displayed the sorted data**: Printed the sorted student data to see how it was organized.
# - **Initialized the groups**: Decided to create three groups and set up empty lists for each one.
# - **Distributed the students**: For each unique profession, filtered the students and distributed them into the groups using a round-robin method.
# - **Calculated the averages**: Created a function to calculate the average score for each group.
# - **Calculated the standard deviation**: Found the initial standard deviation of the group averages to check how spread out they were.
# - **Displayed the initial distribution**: Printed the initial distribution of students in each group, along with their average scores and the standard deviation.
# - **Swapped students**: Defined a function to minimize the standard deviation by swapping students between groups.
#   - Identified which group had the highest average score and which one had the lowest.
#   - Swapped the highest-scoring student from the high group with the lowest-scoring student from the low group, focusing on students with the same profession.
# - **Attempted improvement**: Called the swap function to see if it improved the group averages and standard deviation.
# - **Displayed the updated distribution**: Printed the updated distribution of students in each group and the new standard deviation.
# - **Compared the results**: Showed both the initial and final standard deviations to see how much improvement was made.

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Function that processes each file to reduce creating code again and again
def process_file(file_path):
    # Loading the CSV file into a pandas DataFrame
    students_df = pd.read_csv(file_path)

    # Displaying the original records
    print("\nOriginal Student Data:")
    print(students_df.to_string(index=False))

    # Total Number of groups (k), we can change its values
    k = 3 

    # Step 1: Sorting students by profession and score
    students_sorted = students_df.sort_values(by=['profession', 'score'], ascending=[True, False])

    # Displaying the sorted data
    print("\nSorted Student Data:")
    print(students_sorted[['userId', 'score', 'profession']].to_string(index=False))

    # Step 2: Separating the students by profession and distributing them into groups
    professions = students_sorted['profession'].unique()
    groups = [[] for _ in range(k)]

    for profession in professions:
        profession_group = students_sorted[students_sorted['profession'] == profession]
        for i, (_, student) in enumerate(profession_group.iterrows()):
            groups[i % k].append(student)

    # Step 3: Calculating the average marks for each group
    def calculate_group_averages(groups):
        return [pd.DataFrame(group)['score'].mean() for group in groups]

    group_averages = calculate_group_averages(groups)
    initial_std_dev = np.std(group_averages)

    # Printing the initial group distribution
    print("\nInitial Group Distribution:")
    for i, group in enumerate(groups):
        print(f"\nGroup {i+1}:")
        for student in group:
            print(f"UserId: {student['userId']}, Score: {student['score']}, Profession: {student['profession']}")
        print(f"Average Score: {group_averages[i]:.2f}")

    print(f"\n Initial Standard Deviation of Group Averages: {initial_std_dev:.2f}")

    # Step 4: Strategy to swap students to minimize the standard deviation
    def swap_students(groups, group_averages):
        high_group_idx = np.argmax(group_averages)
        low_group_idx = np.argmin(group_averages)

        high_group = pd.DataFrame(groups[high_group_idx])
        low_group = pd.DataFrame(groups[low_group_idx])

        # Find common professions to swap
        for profession in high_group['profession'].unique():
            high_group_prof = high_group[high_group['profession'] == profession]
            low_group_prof = low_group[low_group['profession'] == profession]

            if not high_group_prof.empty and not low_group_prof.empty:
                # Select highest score from high group and lowest from low group
                high_student = high_group_prof.iloc[0]  # highest scoring student
                low_student = low_group_prof.iloc[-1]   # lowest scoring student

                # Perform the swap
                print(f"\nSwapping UserId {high_student['userId']} with UserId {low_student['userId']}")

                # Remove the students from their current groups by userId
                groups[high_group_idx] = [s for s in groups[high_group_idx] if s['userId'] != high_student['userId']]
                groups[low_group_idx] = [s for s in groups[low_group_idx] if s['userId'] != low_student['userId']]

                # Append the swapped students to their new groups
                groups[high_group_idx].append(low_student)
                groups[low_group_idx].append(high_student)

                # Recalculate group averages
                new_group_averages = calculate_group_averages(groups)
                return np.std(new_group_averages), new_group_averages

        return None, group_averages

    # Step 5: Adding condition to skip swap if standard deviation is <= 2
    if initial_std_dev <= 2:
        print(f"\nInitial Standard Deviation ({initial_std_dev:.2f}) is already less than or equal to 2. No swap performed.")
        final_std_dev = initial_std_dev
    else:
        # Attempting to improve the distribution
        final_std_dev, final_group_averages = swap_students(groups, group_averages)

        # Printing the updated group distribution after swap
        if final_std_dev is not None:
            print("\nUpdated Group Distribution After Swap:")
            for i, group in enumerate(groups):
                print(f"\nGroup {i + 1}:")
                for student in group:
                    print(f"UserId: {student['userId']}, Score: {student['score']}, Profession: {student['profession']}")
                print(f"Updated Average Score: {final_group_averages[i]:.2f}")

            print(f"\nFinal Standard Deviation of Group Averages: {final_std_dev:.2f}")

        else:
            print("\nNo improvements were made.")

    # Displaying both initial and updated standard deviations
    print(f"\nInitial Standard Deviation: {initial_std_dev:.2f}")
    print(f"Final Standard Deviation: {final_std_dev:.2f}" if final_std_dev is not None else f"Final Standard Deviation: {initial_std_dev:.2f}")
    print("\n ******************************************************************* \n")

# List of file paths for all CSV files
file_paths = [
    r'D:\Naila Task\Tuesday 22-Oct-2024\table1.csv',
    r'D:\Naila Task\Tuesday 22-Oct-2024\table2.csv',
    r'D:\Naila Task\Tuesday 22-Oct-2024\table3.csv',
    r'D:\Naila Task\Tuesday 22-Oct-2024\table4.csv',
    r'D:\Naila Task\Tuesday 22-Oct-2024\table5.csv',
    r'D:\Naila Task\Tuesday 22-Oct-2024\table6.csv'
]

# Looping through each file and processing it
for file_path in file_paths:
    print(f"\nProcessing file: {os.path.basename(file_path)}")
    process_file(file_path)
# Out:
# Processing file: table1.csv
#
# Original Student Data:
#  Unnamed: 0  userId  score profession
#           0       1    100   Engineer
#           1       2    100   Engineer
#           2       3    100   Engineer
#           3       4    100     Doctor
#           4       5    100     Doctor
#           5       6     85     Doctor
#           6       7     70     Lawyer
#           7       8     75     Lawyer
#           8       9     60     Lawyer
#           9      10     65   Engineer
#          10      11     55   Engineer
#          11      12     50     Doctor
#          12      13     45     Lawyer
#          13      14     40     Doctor
#          14      15     35     Lawyer
#          15      16     30   Engineer
#          16      17     25     Doctor
#          17      18     20     Lawyer
#
# Sorted Student Data:
#  userId  score profession
#       4    100     Doctor
#       5    100     Doctor
#       6     85     Doctor
#      12     50     Doctor
#      14     40     Doctor
#      17     25     Doctor
#       1    100   Engineer
#       2    100   Engineer
#       3    100   Engineer
#      10     65   Engineer
#      11     55   Engineer
#      16     30   Engineer
#       8     75     Lawyer
#       7     70     Lawyer
#       9     60     Lawyer
#      13     45     Lawyer
#      15     35     Lawyer
#      18     20     Lawyer
#
# Initial Group Distribution:
#
# Group 1:
# UserId: 4, Score: 100, Profession: Doctor
# UserId: 12, Score: 50, Profession: Doctor
# UserId: 1, Score: 100, Profession: Engineer
# UserId: 10, Score: 65, Profession: Engineer
# UserId: 8, Score: 75, Profession: Lawyer
# UserId: 13, Score: 45, Profession: Lawyer
# Average Score: 72.50
#
# Group 2:
# UserId: 5, Score: 100, Profession: Doctor
# UserId: 14, Score: 40, Profession: Doctor
# UserId: 2, Score: 100, Profession: Engineer
# UserId: 11, Score: 55, Profession: Engineer
# UserId: 7, Score: 70, Profession: Lawyer
# UserId: 15, Score: 35, Profession: Lawyer
# Average Score: 66.67
#
# Group 3:
# UserId: 6, Score: 85, Profession: Doctor
# UserId: 17, Score: 25, Profession: Doctor
# UserId: 3, Score: 100, Profession: Engineer
# UserId: 16, Score: 30, Profession: Engineer
# UserId: 9, Score: 60, Profession: Lawyer
# UserId: 18, Score: 20, Profession: Lawyer
# Average Score: 53.33
#
#  Initial Standard Deviation of Group Averages: 8.02
#
# Swapping UserId 4 with UserId 17
#
# Updated Group Distribution After Swap:
#
# Group 1:
# UserId: 12, Score: 50, Profession: Doctor
# UserId: 1, Score: 100, Profession: Engineer
# UserId: 10, Score: 65, Profession: Engineer
# UserId: 8, Score: 75, Profession: Lawyer
# UserId: 13, Score: 45, Profession: Lawyer
# UserId: 17, Score: 25, Profession: Doctor
# Updated Average Score: 60.00
#
# Group 2:
# UserId: 5, Score: 100, Profession: Doctor
# UserId: 14, Score: 40, Profession: Doctor
# UserId: 2, Score: 100, Profession: Engineer
# UserId: 11, Score: 55, Profession: Engineer
# UserId: 7, Score: 70, Profession: Lawyer
# UserId: 15, Score: 35, Profession: Lawyer
# Updated Average Score: 66.67
#
# Group 3:
# UserId: 6, Score: 85, Profession: Doctor
# UserId: 3, Score: 100, Profession: Engineer
# UserId: 16, Score: 30, Profession: Engineer
# UserId: 9, Score: 60, Profession: Lawyer
# UserId: 18, Score: 20, Profession: Lawyer
# UserId: 4, Score: 100, Profession: Doctor
# Updated Average Score: 65.83
#
# Final Standard Deviation of Group Averages: 2.97
#
# Initial Standard Deviation: 8.02
# Final Standard Deviation: 2.97
#
#  *******************************************************************
#
#
# Processing file: table2.csv
#
# Original Student Data:
#  Unnamed: 0  userId  score profession   group
#           1      17     99     Doctor Group 0
#           3      20     60  Scientist Group 0
#           4       4     87    Teacher Group 0
#          15       3     23     Artist Group 0
#          17       1      5   Engineer Group 0
#           5      18     35     Artist Group 1
#           6       2     98     Doctor Group 1
#           8       5     55  Scientist Group 1
#           9      19     83    Teacher Group 1
#          12      16      6   Engineer Group 1
#           7       6     19   Engineer Group 2
#          10       8     33     Artist Group 2
#          11       7     94     Doctor Group 2
#          13      15     51  Scientist Group 2
#          14       9     79    Teacher Group 2
#           0      13     45     Artist Group 3
#           2      11     28   Engineer Group 3
#          16      12     91     Doctor Group 3
#          18      10     43  Scientist Group 3
#          19      14     72    Teacher Group 3
#
# Sorted Student Data:
#  userId  score profession
#      13     45     Artist
#      18     35     Artist
#       8     33     Artist
#       3     23     Artist
#      17     99     Doctor
#       2     98     Doctor
#       7     94     Doctor
#      12     91     Doctor
#      11     28   Engineer
#       6     19   Engineer
#      16      6   Engineer
#       1      5   Engineer
#      20     60  Scientist
#       5     55  Scientist
#      15     51  Scientist
#      10     43  Scientist
#       4     87    Teacher
#      19     83    Teacher
#       9     79    Teacher
#      14     72    Teacher
#
# Initial Group Distribution:
#
# Group 1:
# UserId: 13, Score: 45, Profession: Artist
# UserId: 3, Score: 23, Profession: Artist
# UserId: 17, Score: 99, Profession: Doctor
# UserId: 12, Score: 91, Profession: Doctor
# UserId: 11, Score: 28, Profession: Engineer
# UserId: 1, Score: 5, Profession: Engineer
# UserId: 20, Score: 60, Profession: Scientist
# UserId: 10, Score: 43, Profession: Scientist
# UserId: 4, Score: 87, Profession: Teacher
# UserId: 14, Score: 72, Profession: Teacher
# Average Score: 55.30
#
# Group 2:
# UserId: 18, Score: 35, Profession: Artist
# UserId: 2, Score: 98, Profession: Doctor
# UserId: 6, Score: 19, Profession: Engineer
# UserId: 5, Score: 55, Profession: Scientist
# UserId: 19, Score: 83, Profession: Teacher
# Average Score: 58.00
#
# Group 3:
# UserId: 8, Score: 33, Profession: Artist
# UserId: 7, Score: 94, Profession: Doctor
# UserId: 16, Score: 6, Profession: Engineer
# UserId: 15, Score: 51, Profession: Scientist
# UserId: 9, Score: 79, Profession: Teacher
# Average Score: 52.60
#
#  Initial Standard Deviation of Group Averages: 2.20
#
# Swapping UserId 18 with UserId 8
#
# Updated Group Distribution After Swap:
#
# Group 1:
# UserId: 13, Score: 45, Profession: Artist
# UserId: 3, Score: 23, Profession: Artist
# UserId: 17, Score: 99, Profession: Doctor
# UserId: 12, Score: 91, Profession: Doctor
# UserId: 11, Score: 28, Profession: Engineer
# UserId: 1, Score: 5, Profession: Engineer
# UserId: 20, Score: 60, Profession: Scientist
# UserId: 10, Score: 43, Profession: Scientist
# UserId: 4, Score: 87, Profession: Teacher
# UserId: 14, Score: 72, Profession: Teacher
# Updated Average Score: 55.30
#
# Group 2:
# UserId: 2, Score: 98, Profession: Doctor
# UserId: 6, Score: 19, Profession: Engineer
# UserId: 5, Score: 55, Profession: Scientist
# UserId: 19, Score: 83, Profession: Teacher
# UserId: 8, Score: 33, Profession: Artist
# Updated Average Score: 57.60
#
# Group 3:
# UserId: 7, Score: 94, Profession: Doctor
# UserId: 16, Score: 6, Profession: Engineer
# UserId: 15, Score: 51, Profession: Scientist
# UserId: 9, Score: 79, Profession: Teacher
# UserId: 18, Score: 35, Profession: Artist
# Updated Average Score: 53.00
#
# Final Standard Deviation of Group Averages: 1.88
#
# Initial Standard Deviation: 2.20
# Final Standard Deviation: 1.88
#
#  *******************************************************************
#
#
# Processing file: table3.csv
#
# Original Student Data:
#  Unnamed: 0  userId  score profession   group
#           0       9     60     Artist Group 0
#           1      18     35     Doctor Group 0
#           2       5     15     Doctor Group 0
#           3       1     80   Engineer Group 0
#           4      20     20  Scientist Group 2
#           5       8     55     Artist Group 1
#           6      17     30     Doctor Group 1
#           7       4     10     Doctor Group 3
#           8      14     78  Scientist Group 1
#           9      10     90    Teacher Group 1
#          10       7     50     Artist Group 2
#          11      16     25     Doctor Group 3
#          12       3     82   Engineer Group 2
#          13      15     77  Scientist Group 0
#          14      12     88    Teacher Group 2
#          15      19     40     Doctor Group 2
#          16       6     20     Doctor Group 1
#          17       2     81   Engineer Group 3
#          18      13     75  Scientist Group 3
#          19      11     85    Teacher Group 3
#
# Sorted Student Data:
#  userId  score profession
#       9     60     Artist
#       8     55     Artist
#       7     50     Artist
#      19     40     Doctor
#      18     35     Doctor
#      17     30     Doctor
#      16     25     Doctor
#       6     20     Doctor
#       5     15     Doctor
#       4     10     Doctor
#       3     82   Engineer
#       2     81   Engineer
#       1     80   Engineer
#      14     78  Scientist
#      15     77  Scientist
#      13     75  Scientist
#      20     20  Scientist
#      10     90    Teacher
#      12     88    Teacher
#      11     85    Teacher
#
# Initial Group Distribution:
#
# Group 1:
# UserId: 9, Score: 60, Profession: Artist
# UserId: 19, Score: 40, Profession: Doctor
# UserId: 16, Score: 25, Profession: Doctor
# UserId: 4, Score: 10, Profession: Doctor
# UserId: 3, Score: 82, Profession: Engineer
# UserId: 14, Score: 78, Profession: Scientist
# UserId: 20, Score: 20, Profession: Scientist
# UserId: 10, Score: 90, Profession: Teacher
# Average Score: 50.62
#
# Group 2:
# UserId: 8, Score: 55, Profession: Artist
# UserId: 18, Score: 35, Profession: Doctor
# UserId: 6, Score: 20, Profession: Doctor
# UserId: 2, Score: 81, Profession: Engineer
# UserId: 15, Score: 77, Profession: Scientist
# UserId: 12, Score: 88, Profession: Teacher
# Average Score: 59.33
#
# Group 3:
# UserId: 7, Score: 50, Profession: Artist
# UserId: 17, Score: 30, Profession: Doctor
# UserId: 5, Score: 15, Profession: Doctor
# UserId: 1, Score: 80, Profession: Engineer
# UserId: 13, Score: 75, Profession: Scientist
# UserId: 11, Score: 85, Profession: Teacher
# Average Score: 55.83
#
#  Initial Standard Deviation of Group Averages: 3.58
#
# Swapping UserId 8 with UserId 9
#
# Updated Group Distribution After Swap:
#
# Group 1:
# UserId: 19, Score: 40, Profession: Doctor
# UserId: 16, Score: 25, Profession: Doctor
# UserId: 4, Score: 10, Profession: Doctor
# UserId: 3, Score: 82, Profession: Engineer
# UserId: 14, Score: 78, Profession: Scientist
# UserId: 20, Score: 20, Profession: Scientist
# UserId: 10, Score: 90, Profession: Teacher
# UserId: 8, Score: 55, Profession: Artist
# Updated Average Score: 50.00
#
# Group 2:
# UserId: 18, Score: 35, Profession: Doctor
# UserId: 6, Score: 20, Profession: Doctor
# UserId: 2, Score: 81, Profession: Engineer
# UserId: 15, Score: 77, Profession: Scientist
# UserId: 12, Score: 88, Profession: Teacher
# UserId: 9, Score: 60, Profession: Artist
# Updated Average Score: 60.17
#
# Group 3:
# UserId: 7, Score: 50, Profession: Artist
# UserId: 17, Score: 30, Profession: Doctor
# UserId: 5, Score: 15, Profession: Doctor
# UserId: 1, Score: 80, Profession: Engineer
# UserId: 13, Score: 75, Profession: Scientist
# UserId: 11, Score: 85, Profession: Teacher
# Updated Average Score: 55.83
#
# Final Standard Deviation of Group Averages: 4.17
#
# Initial Standard Deviation: 3.58
# Final Standard Deviation: 4.17
#
#  *******************************************************************
#
#
# Processing file: table4.csv
#
# Original Student Data:
#  Unnamed: 0  userId  score profession   group
#           0      12    100     Artist Group 0
#           1      14     97     Doctor Group 0
#           2      18    100   Engineer Group 2
#           3      16     95  Scientist Group 2
#           4       7     50    Teacher Group 0
#           5      10     50     Artist Group 1
#           6      13      3     Doctor Group 1
#           7      17      4   Engineer Group 1
#           8      15      1  Scientist Group 3
#           9       8     50    Teacher Group 3
#          10      11      3     Artist Group 2
#          11       1      1     Doctor Group 2
#          12       4      2   Engineer Group 0
#          13       6      1  Scientist Group 0
#          14       9     50    Teacher Group 2
#          15       2     99     Doctor Group 3
#          16       3    100   Engineer Group 3
#          17       5    100  Scientist Group 1
#          18      19     98    Teacher Group 1
#          19      20      2    Teacher Group 3
#
# Sorted Student Data:
#  userId  score profession
#      12    100     Artist
#      10     50     Artist
#      11      3     Artist
#       2     99     Doctor
#      14     97     Doctor
#      13      3     Doctor
#       1      1     Doctor
#      18    100   Engineer
#       3    100   Engineer
#      17      4   Engineer
#       4      2   Engineer
#       5    100  Scientist
#      16     95  Scientist
#      15      1  Scientist
#       6      1  Scientist
#      19     98    Teacher
#       7     50    Teacher
#       8     50    Teacher
#       9     50    Teacher
#      20      2    Teacher
#
# Initial Group Distribution:
#
# Group 1:
# UserId: 12, Score: 100, Profession: Artist
# UserId: 2, Score: 99, Profession: Doctor
# UserId: 1, Score: 1, Profession: Doctor
# UserId: 18, Score: 100, Profession: Engineer
# UserId: 4, Score: 2, Profession: Engineer
# UserId: 5, Score: 100, Profession: Scientist
# UserId: 6, Score: 1, Profession: Scientist
# UserId: 19, Score: 98, Profession: Teacher
# UserId: 9, Score: 50, Profession: Teacher
# Average Score: 61.22
#
# Group 2:
# UserId: 10, Score: 50, Profession: Artist
# UserId: 14, Score: 97, Profession: Doctor
# UserId: 3, Score: 100, Profession: Engineer
# UserId: 16, Score: 95, Profession: Scientist
# UserId: 7, Score: 50, Profession: Teacher
# UserId: 20, Score: 2, Profession: Teacher
# Average Score: 65.67
#
# Group 3:
# UserId: 11, Score: 3, Profession: Artist
# UserId: 13, Score: 3, Profession: Doctor
# UserId: 17, Score: 4, Profession: Engineer
# UserId: 15, Score: 1, Profession: Scientist
# UserId: 8, Score: 50, Profession: Teacher
# Average Score: 12.20
#
#  Initial Standard Deviation of Group Averages: 24.22
#
# Swapping UserId 10 with UserId 11
#
# Updated Group Distribution After Swap:
#
# Group 1:
# UserId: 12, Score: 100, Profession: Artist
# UserId: 2, Score: 99, Profession: Doctor
# UserId: 1, Score: 1, Profession: Doctor
# UserId: 18, Score: 100, Profession: Engineer
# UserId: 4, Score: 2, Profession: Engineer
# UserId: 5, Score: 100, Profession: Scientist
# UserId: 6, Score: 1, Profession: Scientist
# UserId: 19, Score: 98, Profession: Teacher
# UserId: 9, Score: 50, Profession: Teacher
# Updated Average Score: 61.22
#
# Group 2:
# UserId: 14, Score: 97, Profession: Doctor
# UserId: 3, Score: 100, Profession: Engineer
# UserId: 16, Score: 95, Profession: Scientist
# UserId: 7, Score: 50, Profession: Teacher
# UserId: 20, Score: 2, Profession: Teacher
# UserId: 11, Score: 3, Profession: Artist
# Updated Average Score: 57.83
#
# Group 3:
# UserId: 13, Score: 3, Profession: Doctor
# UserId: 17, Score: 4, Profession: Engineer
# UserId: 15, Score: 1, Profession: Scientist
# UserId: 8, Score: 50, Profession: Teacher
# UserId: 10, Score: 50, Profession: Artist
# Updated Average Score: 21.60
#
# Final Standard Deviation of Group Averages: 17.93
#
# Initial Standard Deviation: 24.22
# Final Standard Deviation: 17.93
#
#  *******************************************************************
#
#
# Processing file: table5.csv
#
# Original Student Data:
#  Unnamed: 0  userId  score profession   group
#           0       3     90     Doctor Group 0
#           1       1     98   Engineer Group 0
#           2       9     70   Engineer Group 0
#           3       6     83     Doctor Group 2
#           4       2     92   Engineer Group 1
#           5       5     85    Teacher Group 1
#           6       8     75     Doctor Group 1
#           7       4     87   Engineer Group 2
#           8       7     78    Teacher Group 2
#
# Sorted Student Data:
#  userId  score profession
#       3     90     Doctor
#       6     83     Doctor
#       8     75     Doctor
#       1     98   Engineer
#       2     92   Engineer
#       4     87   Engineer
#       9     70   Engineer
#       5     85    Teacher
#       7     78    Teacher
#
# Initial Group Distribution:
#
# Group 1:
# UserId: 3, Score: 90, Profession: Doctor
# UserId: 1, Score: 98, Profession: Engineer
# UserId: 9, Score: 70, Profession: Engineer
# UserId: 5, Score: 85, Profession: Teacher
# Average Score: 85.75
#
# Group 2:
# UserId: 6, Score: 83, Profession: Doctor
# UserId: 2, Score: 92, Profession: Engineer
# UserId: 7, Score: 78, Profession: Teacher
# Average Score: 84.33
#
# Group 3:
# UserId: 8, Score: 75, Profession: Doctor
# UserId: 4, Score: 87, Profession: Engineer
# Average Score: 81.00
#
#  Initial Standard Deviation of Group Averages: 1.99
#
# Initial Standard Deviation (1.99) is already less than or equal to 2. No swap performed.
#
# Initial Standard Deviation: 1.99
# Final Standard Deviation: 1.99
#
#  *******************************************************************
#
#
# Processing file: table6.csv
#
# Original Student Data:
#  Unnamed: 0    userId                profession  score   group
#           0 Student O              Air Defender 100.00 Group 0
#           1 Student L              Air Defender  73.81 Group 0
#           2 Student M Air Defense Major General  64.29 Group 3
#           3 Student I             Fighter Pilot 100.00 Group 1
#           4 Student R           Transport Pilot  47.62 Group 0
#           5 Student K              Air Defender 100.00 Group 1
#           6 Student P              Air Defender  71.43 Group 1
#           7 Student Q Air Defense Major General  19.05 Group 1
#           8 Student N             Fighter Pilot   0.00 Group 0
#           9 Student E           Transport Pilot  21.43 Group 1
#          10 Student B              Air Defender  83.33 Group 2
#          11 Student C              Air Defender  33.33 Group 2
#          12 Student D             Captain Pilot  26.19 Group 2
#          13 Student A             Major Officer 100.00 Group 2
#          14 Student G              Air Defender  76.19 Group 3
#          15 Student H Air Defense Major General 100.00 Group 0
#          16 Student J                  Engineer  78.57 Group 3
#          17 Student F             Major Officer  21.43 Group 3
#
# Sorted Student Data:
#    userId  score                profession
# Student O 100.00              Air Defender
# Student K 100.00              Air Defender
# Student B  83.33              Air Defender
# Student G  76.19              Air Defender
# Student L  73.81              Air Defender
# Student P  71.43              Air Defender
# Student C  33.33              Air Defender
# Student H 100.00 Air Defense Major General
# Student M  64.29 Air Defense Major General
# Student Q  19.05 Air Defense Major General
# Student D  26.19             Captain Pilot
# Student J  78.57                  Engineer
# Student I 100.00             Fighter Pilot
# Student N   0.00             Fighter Pilot
# Student A 100.00             Major Officer
# Student F  21.43             Major Officer
# Student R  47.62           Transport Pilot
# Student E  21.43           Transport Pilot
#
# Initial Group Distribution:
#
# Group 1:
# UserId: Student O, Score: 100.0, Profession: Air Defender
# UserId: Student G, Score: 76.19, Profession: Air Defender
# UserId: Student C, Score: 33.33, Profession: Air Defender
# UserId: Student H, Score: 100.0, Profession: Air Defense Major General
# UserId: Student D, Score: 26.19, Profession: Captain Pilot
# UserId: Student J, Score: 78.57, Profession: Engineer
# UserId: Student I, Score: 100.0, Profession: Fighter Pilot
# UserId: Student A, Score: 100.0, Profession: Major Officer
# UserId: Student R, Score: 47.62, Profession: Transport Pilot
# Average Score: 73.54
#
# Group 2:
# UserId: Student K, Score: 100.0, Profession: Air Defender
# UserId: Student L, Score: 73.81, Profession: Air Defender
# UserId: Student M, Score: 64.29, Profession: Air Defense Major General
# UserId: Student N, Score: 0.0, Profession: Fighter Pilot
# UserId: Student F, Score: 21.43, Profession: Major Officer
# UserId: Student E, Score: 21.43, Profession: Transport Pilot
# Average Score: 46.83
#
# Group 3:
# UserId: Student B, Score: 83.33, Profession: Air Defender
# UserId: Student P, Score: 71.43, Profession: Air Defender
# UserId: Student Q, Score: 19.05, Profession: Air Defense Major General
# Average Score: 57.94
#
#  Initial Standard Deviation of Group Averages: 10.96
#
# Swapping UserId Student O with UserId Student L
#
# Updated Group Distribution After Swap:
#
# Group 1:
# UserId: Student G, Score: 76.19, Profession: Air Defender
# UserId: Student C, Score: 33.33, Profession: Air Defender
# UserId: Student H, Score: 100.0, Profession: Air Defense Major General
# UserId: Student D, Score: 26.19, Profession: Captain Pilot
# UserId: Student J, Score: 78.57, Profession: Engineer
# UserId: Student I, Score: 100.0, Profession: Fighter Pilot
# UserId: Student A, Score: 100.0, Profession: Major Officer
# UserId: Student R, Score: 47.62, Profession: Transport Pilot
# UserId: Student L, Score: 73.81, Profession: Air Defender
# Updated Average Score: 70.63
#
# Group 2:
# UserId: Student K, Score: 100.0, Profession: Air Defender
# UserId: Student M, Score: 64.29, Profession: Air Defense Major General
# UserId: Student N, Score: 0.0, Profession: Fighter Pilot
# UserId: Student F, Score: 21.43, Profession: Major Officer
# UserId: Student E, Score: 21.43, Profession: Transport Pilot
# UserId: Student O, Score: 100.0, Profession: Air Defender
# Updated Average Score: 51.19
#
# Group 3:
# UserId: Student B, Score: 83.33, Profession: Air Defender
# UserId: Student P, Score: 71.43, Profession: Air Defender
# UserId: Student Q, Score: 19.05, Profession: Air Defense Major General
# Updated Average Score: 57.94
#
# Final Standard Deviation of Group Averages: 8.06
#
# Initial Standard Deviation: 10.96
# Final Standard Deviation: 8.06
#
#  *******************************************************************
